# %%
import pandas as pd

# %% [markdown]
# # Drug Consumption Data

# %% [markdown]
# **Output Encoding System**
#
# CL0 Never Used 27
# CL1 Used over a Decade Ago
# CL2 Used in Last Decade
# CL3 Used in Last Year
# CL4 Used in Last Month
# CL5 Used in Last Week
# CL6 Used in Last Day

# %%
#col_names = ['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'N-score', 'E-score', 'O-score', 'A-score', 'C-score', 'I-score', 'SS', 'Alcohol_Out', 'Amphet_Out', 'Amyl_Out', 'Benzos_Out', 'Caffeine_Out', 'Cannabis_Out', 'Chocolate_Out', 'Coke_Out', 'Crack_Out', 'Ecstasy_Out', 'Heroin_Out', 'Ketamine_Out', 'Legalh_Out', 'LSD_Out', 'Methadone_Out', 'Meth_Out', 'Mushrooms_Out', 'Nicotine_Out', 'Semeron_Out', 'VSA_Out']
df = pd.read_csv('drug_consumption.data', names=['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'N-score', 'E-score', 'O-score', 'A-score', 'C-score', 'I-score', 'SS', 'Alcohol_Out', 'Amphet_Out', 'Amyl_Out', 'Benzos_Out', 'Caffeine_Out', 'Cannabis_Out', 'Chocolate_Out', 'Coke_Out', 'Crack_Out', 'Ecstasy_Out', 'Heroin_Out', 'Ketamine_Out', 'Legalh_Out', 'LSD_Out', 'Methadone_Out', 'Meth_Out', 'Mushrooms_Out', 'Nicotine_Out', 'Semeron_Out', 'VSA_Out'])
df
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity  N-score  E-score  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
# ...

# %%
# No missing values
df.isna().sum()
# Out:
# ID                  0
# Age                 0
# Gender              0
# Education           0
# Country             0
# Ethnicity           0
# N-score             0
# E-score             0
# O-score             0
# A-score             0
# C-score             0
# I-score             0
# SS                  0
# Alcohol_Out         0
# Amphet_Out          0
# Amyl_Out            0
# Benzos_Out          0
# Caffeine_Out        0
# Cannabis_Out        0
# Chocolate_Out       0
# Coke_Out            0
# Crack_Out           0
# Ecstasy_Out         0
# Heroin_Out          0
# Ketamine_Out        0
# Legalh_Out          0
# LSD_Out             0
# Methadone_Out       0
# Meth_Out            0
# Mushrooms_Out       0
# Nicotine_Out        0
# Semeron_Out         0
# VSA_Out          1885
# dtype: int64

# %%
# potential subset
df = df.filter(items=['ID', 'Age', 'Gender', 'Education', 'Country', 'Ethnicity', 'Alcohol_Out', 'Cannabis_Out', 'Coke_Out', 'Crack_Out', 'Heroin_Out', 'Nicotine_Out'])
df
# Out:
#         ID      Age   Gender  Education  Country  Ethnicity Alcohol_Out  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600         CL5
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685         CL5
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685         CL6
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685         CL4
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685         CL4
# ...    ...      ...      ...        ...      ...        ...         ...
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685         CL5
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685         CL5
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685         CL4
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685         CL5
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685         CL4
#
#      Cannabis_Out Coke_Out Crack_Out Heroin_Out Nicotine_Out
# ...

# %% [markdown]
# # Spotify Data

# %%
music = pd.read_csv('genres_v2.csv', low_memory=False)
music
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.831   0.814    2    -7.364     1       0.4200      0.059800
# 1             0.719   0.493    8    -7.230     1       0.0794      0.401000
# 2             0.850   0.893    5    -4.783     1       0.0623      0.013800
# 3             0.476   0.781    0    -4.710     1       0.1030      0.023700
# 4             0.798   0.624    2    -7.668     1       0.2930      0.217000
# ...             ...     ...  ...       ...   ...          ...           ...
# 42300         0.528   0.693    4    -5.148     1       0.0304      0.031500
# 42301         0.517   0.768    0    -7.922     0       0.0479      0.022500
# 42302         0.361   0.821    8    -3.102     1       0.0505      0.026000
# 42303         0.477   0.921    6    -4.777     0       0.0392      0.000551
# 42304         0.529   0.945    9    -5.862     1       0.0615      0.001890
#
# ...

# %%
music.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  42305.000000  42305.000000  42305.000000  42305.000000  42305.000000
# mean       0.639364      0.762516      5.370240     -6.465442      0.549462
# std        0.156617      0.183823      3.666145      2.941165      0.497553
# min        0.065100      0.000243      0.000000    -33.357000      0.000000
# 25%        0.524000      0.632000      1.000000     -8.161000      0.000000
# 50%        0.646000      0.803000      6.000000     -6.234000      1.000000
# 75%        0.766000      0.923000      9.000000     -4.513000      1.000000
# max        0.988000      1.000000     11.000000      3.148000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  42305.000000  42305.000000      42305.000000  42305.000000
# mean       0.136561      0.096160          0.283048      0.214079
# std        0.126168      0.170827          0.370791      0.175576
# ...

# %%
# song name has missing values which is problematic
music.isna().sum()
# Out:
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# type                    0
# id                      0
# uri                     0
# track_href              0
# analysis_url            0
# duration_ms             0
# time_signature          0
# genre                   0
# song_name           20786
# Unnamed: 0          21525
# title               21525
# dtype: int64
